# %%
#used mainly in the data interpretation, analysis, and visulaization
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

#used in the training 
import torch #all around dataset to be used throughout the training and validation process
from tqdm import tqdm_notebook as tqdm 
from torch.utils.data.dataset import Dataset #used in transformation
from torch.utils.data import DataLoader #creating a dataloader
from torch.optim.lr_scheduler import StepLR#Training Scheduler 
import time # early exit mechanic if validation doesn't improve.


#Dataset splitting

from sklearn.model_selection import train_test_split

#Cluster Checking
from sklearn.cluster import KMeans

# %%
movies = pd.read_csv('C:/Users/yohan/OneDrive/Desktop/archive/movies.csv')
ratings = pd.read_csv('C:/Users/yohan/OneDrive/Desktop/archive/ratings.csv')
tags = pd.read_csv('C:/Users/yohan/OneDrive/Desktop/archive/tags.csv')

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
crating = ratings['rating']
cgenre = movies['genres']
dfratings = pd.DataFrame(ratings)
dfmovies = pd.DataFrame(movies)
dftags = pd.DataFrame(tags)

# %%
n_users = len(dfratings.userId.unique())
n_movies = len(dfratings.movieId.unique())
print("The number of unique users is: ",n_users)
print("The number of unique users is: ",n_movies)
print("The total elements is: ",n_users * n_movies)
# Out:
# The number of unique users is:  610
# The number of unique users is:  9724
# The total elements is:  5931640

# %%
# simple data analyisis
print(np.mean(crating))
print(np.median(crating))
print(crating.mode()[0])
print(np.std(crating,ddof=1))
# Out:
# 3.501556983616962
# 3.5
# 4.0
# 1.0425292390605359

# %%
# simple data representation 
# Bar Chart
sns.barplot(data=dfratings, x='rating', y='timestamp', color='black')  
plt.title('Bar Chart Example')
plt.show()

# %%
#countplot of the ratings
sns.countplot(data = dfratings, x = 'rating', color = 'skyblue')
plt.title('Rating Graph')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %%
#world cloud for the movie genre 

text = " ".join(dfmovies['genres'].dropna())
wordcloud = WordCloud(width = 7000, height = 5000, background_color= 'white').generate(text)
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# word cloud for tags 
text = " ".join(dftags['tag'].dropna())
wordcloud = WordCloud(width = 7000, height = 5000, background_color = 'white').generate(text)
plt.imshow(wordcloud, interpolation = "bilinear")
plt.axis('off')
plt.show()

# %%
# Modeling and the real hash work
# We're going to be using Matrix Factorization and Collaborative System to train
# K Means Clustering is used to test

class MartixFactorization(torch.nn.Module):
    def __init__(self, n_users, n_movies, n_factors = 20):
        super().__init__()
        self.user_factors = torch.nn.Embedding(n_users, n_factors)
        self.movie_factors = torch.nn.Embedding(n_movies, n_factors)
        
        self.user_factors.weight.data.uniform_(0,0.05)
        self.movie_factors.weight.data.uniform_(0,0.05)

    def forward(self, data):
        users, movies = data[:,0], data[:,1]
        return (self.user_factors(users)*self.movie_factors(movies)).sum(1)

    def predict(self, user, movies):
        return self.forward(user,movies)

# %%
class Loader(Dataset):
    def __init__(self,data):
        self.ratings = data.copy()
        
     
        users = dfratings.userId.unique()
        movies = dfratings.movieId.unique()
        
       
        

        self.userid2idx = {o:i for i,o in enumerate(users)}
        self.movieid2idx = {o:i for i,o in enumerate(movies)}
        

        self.idx2userid = {i:o for o,i in self.userid2idx.items()}
        self.idx2movieid = {i:o for o,i in self.movieid2idx.items()}
        

        self.ratings.movieId = dfratings.movieId.apply(lambda x: self.movieid2idx[x])
        self.ratings.userId = dfratings.userId.apply(lambda x: self.userid2idx[x])
        
        
        self.x = self.ratings.drop(['rating', 'timestamp'], axis=1).values
        self.y = self.ratings['rating'].values
        self.x, self.y = torch.tensor(self.x), torch.tensor(self.y) 

    def __getitem__(self, index):
        return (self.x[index], self.y[index])

    def __len__(self):
        return len(self.ratings)

# %%
# redefining precision k to fit that algorithm 

def precision_at_k(predictions, k, relevance_threshold=4.0):
    precision_list = []

    for user_id, user_data in predictions.items():
        # Get the top K movies based on predicted rating
        top_k_items = user_data[:k]

        # Identify relevant items based on true rating
        relevant_items = [movie_id for _, true_rating, _ in top_k_items if true_rating >= relevance_threshold]

        # Calculate the precision at K (how many of the top K are relevant)
        precision_at_k = len(relevant_items) / k
        precision_list.append(precision_at_k)

    return np.mean(precision_list)

# %%
#splitting the dataset into two, to train and test it.
train_data, test_data = train_test_split(dfratings, test_size=0.1, random_state=42)
train_data, val_data = train_test_split(train_data, test_size = 0.1, random_state = 42)

num_epochs = 128

cuda = False 

model = MartixFactorization(n_users, n_movies, n_factors= 20 )

# MSE loss
loss_fn = torch.nn.MSELoss()

# ADAM optimizier
optimizer = torch.optim.Adam(model.parameters(), lr= 0.0025)

# Scheduler 
scheduler = StepLR(optimizer, step_size=10, gamma=0.15)

#Loader 
train_set = Loader(train_data)
val_set = Loader(val_data)
test_set = Loader(test_data)

#Data_loader wrapping 
train_loader = DataLoader(train_set, 128, shuffle=True)
val_loader = DataLoader(val_set, 128, shuffle = False)
test_loader = DataLoader(test_set, 128, shuffle = False)

# %%
# patience = 10 
# best_val_loss = float('inf')
# epochs_without_improvement = 0

for it in tqdm(range(num_epochs)):
    # Training_section_start 
    
    model.train()
    train_losses = []

    start_time = time.time()
    for x, y in train_loader:
          
            optimizer.zero_grad()
            outputs = model(x)
        
            train_loss = loss_fn(outputs.squeeze(), y.type(torch.float32))
            train_losses.append(train_loss.item())
        
            train_loss.backward()
            optimizer.step()
    
    epoch_time = time.time() - start_time
    
 
    avg_train_loss = sum(train_losses)/len(train_losses)    

    # Training_section_end

    # Eval_section_start

    model.eval()
    val_losses = []
    with torch.no_grad():
        for x,y in val_loader: 
            outputs = model(x)
            val_loss = loss_fn(outputs.squeeze(), y.type(torch.float32))
            val_losses.append(val_loss.item())

    avg_val_loss = np.mean(val_losses)
    # Eval_section_end

    # Print Section 
    print(f"Epoch {it + 1}/{num_epochs} - "f"Train Loss: {avg_train_loss:.4f}, "f"Val Loss: {avg_val_loss:.4f}, "f"Epoch Time: {epoch_time:.2f} seconds")


    # Improvement checker for validation loss and early stopper

    # if avg_val_loss < best_val_loss: 
    #     best_val_loss = avg_val_loss
    #     epochs_without_improvement = 0 
    # else: 
    #     epochs_without_improvement += 1

    # if epochs_without_improvement >= patience:
    #     print("Early stopping triggered, No improvement in validation for {} epochs")
    #     break
        
    scheduler.step()
# Out:
# C:\Users\yohan\AppData\Local\Temp\ipykernel_10052\3430896281.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for it in tqdm(range(num_epochs)):
#   0%|          | 0/128 [00:00<?, ?it/s]
# Epoch 1/128 - Train Loss: 6.0894, Val Loss: 2.2383, Epoch Time: 3.13 seconds
# Epoch 2/128 - Train Loss: 1.4585, Val Loss: 1.4290, Epoch Time: 2.88 seconds
# Epoch 3/128 - Train Loss: 0.9723, Val Loss: 1.2625, Epoch Time: 3.23 seconds
# Epoch 4/128 - Train Loss: 0.8234, Val Loss: 1.2166, Epoch Time: 3.06 seconds
# Epoch 5/128 - Train Loss: 0.7615, Val Loss: 1.1886, Epoch Time: 2.88 seconds
# Epoch 6/128 - Train Loss: 0.7348, Val Loss: 1.1964, Epoch Time: 3.06 seconds
# Epoch 7/128 - Train Loss: 0.7219, Val Loss: 1.1951, Epoch Time: 3.06 seconds
# Epoch 8/128 - Train Loss: 0.7155, Val Loss: 1.2038, Epoch Time: 2.87 seconds
# Epoch 9/128 - Train Loss: 0.7101, Val Loss: 1.1953, Epoch Time: 3.06 seconds
# Epoch 10/128 - Train Loss: 0.6989, Val Loss: 1.2015, Epoch Time: 3.03 seconds
# Epoch 11/128 - Train Loss: 0.6250, Val Loss: 1.1718, Epoch Time: 2.89 seconds
# Epoch 12/128 - Train Loss: 0.6055, Val Loss: 1.1644, Epoch Time: 2.85 seconds
# Epoch 13/128 - Train Loss: 0.5978, Val Loss: 1.1619, Epoch Time: 3.25 seconds
# Epoch 14/128 - Train Loss: 0.5936, Val Loss: 1.1608, Epoch Time: 3.42 seconds
# Epoch 15/128 - Train Loss: 0.5894, Val Loss: 1.1597, Epoch Time: 2.86 seconds
# Epoch 16/128 - Train Loss: 0.5840, Val Loss: 1.1588, Epoch Time: 3.04 seconds
# Epoch 17/128 - Train Loss: 0.5794, Val Loss: 1.1588, Epoch Time: 2.94 seconds
# Epoch 18/128 - Train Loss: 0.5742, Val Loss: 1.1586, Epoch Time: 2.86 seconds
# Epoch 19/128 - Train Loss: 0.5690, Val Loss: 1.1582, Epoch Time: 3.07 seconds
# Epoch 20/128 - Train Loss: 0.5633, Val Loss: 1.1575, Epoch Time: 3.13 seconds
# Epoch 21/128 - Train Loss: 0.5457, Val Loss: 1.1571, Epoch Time: 3.16 seconds
# Epoch 22/128 - Train Loss: 0.5438, Val Loss: 1.1569, Epoch Time: 3.75 seconds
# Epoch 23/128 - Train Loss: 0.5430, Val Loss: 1.1566, Epoch Time: 3.37 seconds
# Epoch 24/128 - Train Loss: 0.5420, Val Loss: 1.1565, Epoch Time: 3.09 seconds
# Epoch 25/128 - Train Loss: 0.5407, Val Loss: 1.1564, Epoch Time: 3.11 seconds
# Epoch 26/128 - Train Loss: 0.5400, Val Loss: 1.1563, Epoch Time: 3.07 seconds
# Epoch 27/128 - Train Loss: 0.5397, Val Loss: 1.1563, Epoch Time: 2.91 seconds
# Epoch 28/128 - Train Loss: 0.5387, Val Loss: 1.1561, Epoch Time: 3.08 seconds
# Epoch 29/128 - Train Loss: 0.5381, Val Loss: 1.1561, Epoch Time: 3.00 seconds
# Epoch 30/128 - Train Loss: 0.5364, Val Loss: 1.1561, Epoch Time: 3.25 seconds
# Epoch 31/128 - Train Loss: 0.5329, Val Loss: 1.1561, Epoch Time: 3.04 seconds
# Epoch 32/128 - Train Loss: 0.5341, Val Loss: 1.1561, Epoch Time: 3.10 seconds
# Epoch 33/128 - Train Loss: 0.5330, Val Loss: 1.1561, Epoch Time: 3.06 seconds
# Epoch 34/128 - Train Loss: 0.5333, Val Loss: 1.1560, Epoch Time: 3.01 seconds
# Epoch 35/128 - Train Loss: 0.5322, Val Loss: 1.1560, Epoch Time: 3.04 seconds
# Epoch 36/128 - Train Loss: 0.5321, Val Loss: 1.1560, Epoch Time: 2.91 seconds
# Epoch 37/128 - Train Loss: 0.5321, Val Loss: 1.1560, Epoch Time: 2.96 seconds
# Epoch 38/128 - Train Loss: 0.5320, Val Loss: 1.1560, Epoch Time: 3.05 seconds
# Epoch 39/128 - Train Loss: 0.5323, Val Loss: 1.1560, Epoch Time: 2.92 seconds
# Epoch 40/128 - Train Loss: 0.5324, Val Loss: 1.1560, Epoch Time: 3.04 seconds
# Epoch 41/128 - Train Loss: 0.5316, Val Loss: 1.1560, Epoch Time: 3.16 seconds
# Epoch 42/128 - Train Loss: 0.5310, Val Loss: 1.1560, Epoch Time: 3.08 seconds
# Epoch 43/128 - Train Loss: 0.5310, Val Loss: 1.1560, Epoch Time: 2.87 seconds
# Epoch 44/128 - Train Loss: 0.5314, Val Loss: 1.1560, Epoch Time: 3.09 seconds
# Epoch 45/128 - Train Loss: 0.5318, Val Loss: 1.1560, Epoch Time: 3.01 seconds
# Epoch 46/128 - Train Loss: 0.5311, Val Loss: 1.1560, Epoch Time: 2.88 seconds
# Epoch 47/128 - Train Loss: 0.5313, Val Loss: 1.1560, Epoch Time: 3.66 seconds
# Epoch 48/128 - Train Loss: 0.5312, Val Loss: 1.1560, Epoch Time: 3.00 seconds
# Epoch 49/128 - Train Loss: 0.5309, Val Loss: 1.1560, Epoch Time: 3.19 seconds
# Epoch 50/128 - Train Loss: 0.5308, Val Loss: 1.1560, Epoch Time: 3.18 seconds
# Epoch 51/128 - Train Loss: 0.5311, Val Loss: 1.1560, Epoch Time: 3.30 seconds
# Epoch 52/128 - Train Loss: 0.5310, Val Loss: 1.1560, Epoch Time: 2.89 seconds
# Epoch 53/128 - Train Loss: 0.5306, Val Loss: 1.1560, Epoch Time: 3.13 seconds
# Epoch 54/128 - Train Loss: 0.5310, Val Loss: 1.1560, Epoch Time: 3.86 seconds
# Epoch 55/128 - Train Loss: 0.5318, Val Loss: 1.1560, Epoch Time: 2.95 seconds
# Epoch 56/128 - Train Loss: 0.5309, Val Loss: 1.1560, Epoch Time: 5.35 seconds
# Epoch 57/128 - Train Loss: 0.5313, Val Loss: 1.1560, Epoch Time: 4.28 seconds
# Epoch 58/128 - Train Loss: 0.5307, Val Loss: 1.1560, Epoch Time: 4.51 seconds
# Epoch 59/128 - Train Loss: 0.5310, Val Loss: 1.1560, Epoch Time: 3.95 seconds
# Epoch 60/128 - Train Loss: 0.5308, Val Loss: 1.1560, Epoch Time: 2.69 seconds
# Epoch 61/128 - Train Loss: 0.5310, Val Loss: 1.1560, Epoch Time: 4.10 seconds
# Epoch 62/128 - Train Loss: 0.5311, Val Loss: 1.1560, Epoch Time: 3.26 seconds
# Epoch 63/128 - Train Loss: 0.5309, Val Loss: 1.1560, Epoch Time: 3.17 seconds
# Epoch 64/128 - Train Loss: 0.5307, Val Loss: 1.1560, Epoch Time: 3.63 seconds
# Epoch 65/128 - Train Loss: 0.5306, Val Loss: 1.1560, Epoch Time: 2.77 seconds
# Epoch 66/128 - Train Loss: 0.5318, Val Loss: 1.1560, Epoch Time: 2.79 seconds
# Epoch 67/128 - Train Loss: 0.5316, Val Loss: 1.1560, Epoch Time: 2.79 seconds
# Epoch 68/128 - Train Loss: 0.5308, Val Loss: 1.1560, Epoch Time: 3.34 seconds
# Epoch 69/128 - Train Loss: 0.5311, Val Loss: 1.1560, Epoch Time: 2.68 seconds
# Epoch 70/128 - Train Loss: 0.5306, Val Loss: 1.1560, Epoch Time: 3.79 seconds
# Epoch 71/128 - Train Loss: 0.5309, Val Loss: 1.1560, Epoch Time: 4.33 seconds
# Epoch 72/128 - Train Loss: 0.5309, Val Loss: 1.1560, Epoch Time: 4.59 seconds
# Epoch 73/128 - Train Loss: 0.5310, Val Loss: 1.1560, Epoch Time: 4.82 seconds
# Epoch 74/128 - Train Loss: 0.5313, Val Loss: 1.1560, Epoch Time: 3.54 seconds
# Epoch 75/128 - Train Loss: 0.5311, Val Loss: 1.1560, Epoch Time: 2.64 seconds
# Epoch 76/128 - Train Loss: 0.5311, Val Loss: 1.1560, Epoch Time: 2.51 seconds
# Epoch 77/128 - Train Loss: 0.5307, Val Loss: 1.1560, Epoch Time: 2.57 seconds
# Epoch 78/128 - Train Loss: 0.5309, Val Loss: 1.1560, Epoch Time: 2.68 seconds
# Epoch 79/128 - Train Loss: 0.5309, Val Loss: 1.1560, Epoch Time: 2.65 seconds
# Epoch 80/128 - Train Loss: 0.5308, Val Loss: 1.1560, Epoch Time: 3.36 seconds
# Epoch 81/128 - Train Loss: 0.5316, Val Loss: 1.1560, Epoch Time: 2.53 seconds
# Epoch 82/128 - Train Loss: 0.5310, Val Loss: 1.1560, Epoch Time: 2.67 seconds
# Epoch 83/128 - Train Loss: 0.5309, Val Loss: 1.1560, Epoch Time: 2.87 seconds
# Epoch 84/128 - Train Loss: 0.5311, Val Loss: 1.1560, Epoch Time: 2.67 seconds
# Epoch 85/128 - Train Loss: 0.5312, Val Loss: 1.1560, Epoch Time: 2.87 seconds
# Epoch 86/128 - Train Loss: 0.5305, Val Loss: 1.1560, Epoch Time: 3.01 seconds
# Epoch 87/128 - Train Loss: 0.5311, Val Loss: 1.1560, Epoch Time: 2.60 seconds
# Epoch 88/128 - Train Loss: 0.5309, Val Loss: 1.1560, Epoch Time: 2.62 seconds
# Epoch 89/128 - Train Loss: 0.5310, Val Loss: 1.1560, Epoch Time: 3.60 seconds
# Epoch 90/128 - Train Loss: 0.5308, Val Loss: 1.1560, Epoch Time: 3.64 seconds
# Epoch 91/128 - Train Loss: 0.5318, Val Loss: 1.1560, Epoch Time: 2.50 seconds
# Epoch 92/128 - Train Loss: 0.5314, Val Loss: 1.1560, Epoch Time: 3.13 seconds
# Epoch 93/128 - Train Loss: 0.5311, Val Loss: 1.1560, Epoch Time: 2.82 seconds
# Epoch 94/128 - Train Loss: 0.5316, Val Loss: 1.1560, Epoch Time: 2.51 seconds
# Epoch 95/128 - Train Loss: 0.5305, Val Loss: 1.1560, Epoch Time: 2.70 seconds
# Epoch 96/128 - Train Loss: 0.5309, Val Loss: 1.1560, Epoch Time: 2.99 seconds
# Epoch 97/128 - Train Loss: 0.5305, Val Loss: 1.1560, Epoch Time: 3.73 seconds
# Epoch 98/128 - Train Loss: 0.5306, Val Loss: 1.1560, Epoch Time: 3.72 seconds
# Epoch 99/128 - Train Loss: 0.5307, Val Loss: 1.1560, Epoch Time: 2.66 seconds
# Epoch 100/128 - Train Loss: 0.5308, Val Loss: 1.1560, Epoch Time: 2.62 seconds
# Epoch 101/128 - Train Loss: 0.5312, Val Loss: 1.1560, Epoch Time: 3.42 seconds
# Epoch 102/128 - Train Loss: 0.5312, Val Loss: 1.1560, Epoch Time: 2.83 seconds
# Epoch 103/128 - Train Loss: 0.5305, Val Loss: 1.1560, Epoch Time: 3.46 seconds
# Epoch 104/128 - Train Loss: 0.5309, Val Loss: 1.1560, Epoch Time: 3.28 seconds
# Epoch 105/128 - Train Loss: 0.5311, Val Loss: 1.1560, Epoch Time: 4.61 seconds
# Epoch 106/128 - Train Loss: 0.5310, Val Loss: 1.1560, Epoch Time: 2.58 seconds
# Epoch 107/128 - Train Loss: 0.5319, Val Loss: 1.1560, Epoch Time: 3.73 seconds
# Epoch 108/128 - Train Loss: 0.5310, Val Loss: 1.1560, Epoch Time: 2.81 seconds
# Epoch 109/128 - Train Loss: 0.5310, Val Loss: 1.1560, Epoch Time: 3.19 seconds
# Epoch 110/128 - Train Loss: 0.5321, Val Loss: 1.1560, Epoch Time: 4.00 seconds
# Epoch 111/128 - Train Loss: 0.5321, Val Loss: 1.1560, Epoch Time: 2.79 seconds
# Epoch 112/128 - Train Loss: 0.5312, Val Loss: 1.1560, Epoch Time: 2.76 seconds
# Epoch 113/128 - Train Loss: 0.5314, Val Loss: 1.1560, Epoch Time: 2.78 seconds
# Epoch 114/128 - Train Loss: 0.5315, Val Loss: 1.1560, Epoch Time: 2.69 seconds
# Epoch 115/128 - Train Loss: 0.5320, Val Loss: 1.1560, Epoch Time: 2.61 seconds
# Epoch 116/128 - Train Loss: 0.5309, Val Loss: 1.1560, Epoch Time: 2.92 seconds
# Epoch 117/128 - Train Loss: 0.5314, Val Loss: 1.1560, Epoch Time: 3.49 seconds
# Epoch 118/128 - Train Loss: 0.5309, Val Loss: 1.1560, Epoch Time: 3.96 seconds
# Epoch 119/128 - Train Loss: 0.5309, Val Loss: 1.1560, Epoch Time: 6.72 seconds
# Epoch 120/128 - Train Loss: 0.5311, Val Loss: 1.1560, Epoch Time: 5.51 seconds
# Epoch 121/128 - Train Loss: 0.5319, Val Loss: 1.1560, Epoch Time: 3.22 seconds
# Epoch 122/128 - Train Loss: 0.5308, Val Loss: 1.1560, Epoch Time: 3.53 seconds
# Epoch 123/128 - Train Loss: 0.5310, Val Loss: 1.1560, Epoch Time: 4.97 seconds
# Epoch 124/128 - Train Loss: 0.5311, Val Loss: 1.1560, Epoch Time: 3.83 seconds
# Epoch 125/128 - Train Loss: 0.5312, Val Loss: 1.1560, Epoch Time: 3.58 seconds
# Epoch 126/128 - Train Loss: 0.5310, Val Loss: 1.1560, Epoch Time: 4.82 seconds
# Epoch 127/128 - Train Loss: 0.5309, Val Loss: 1.1560, Epoch Time: 3.82 seconds
# Epoch 128/128 - Train Loss: 0.5310, Val Loss: 1.1560, Epoch Time: 4.54 seconds

# %%
model.eval()
test_losses = []
true_ratings, predicted_ratings = [],[]
for x, y in train_loader:
          
    optimizer.zero_grad()
    outputs = model(x)
    test_loss = loss_fn(outputs.squeeze(), y.type(torch.float32))
    test_losses.append(test_loss.item())

    predictions = outputs.detach().cpu().numpy().squeeze()

    true_ratings.extend(y.cpu().numpy()) #stored later for precision k test
    predicted_ratings.extend(predictions) #same for this


avg_test_loss = np.mean(test_losses)

            
print(f"Test Loss: {avg_test_loss:.4f}")
# Out:
# Test Loss: 0.5307

# %%
trained_movie_embeddings = model.movie_factors.weight.data.cpu().numpy()
kmeans = KMeans(n_clusters=15, random_state=0).fit(trained_movie_embeddings)
     
for cluster in range(15):
    print("Cluster #{}".format(cluster))
    movs = []
   
    for movidx in np.where(kmeans.labels_ == cluster)[0]:
        movid = train_set.idx2movieid[movidx]

        rat_count = len(dfratings.loc[dfratings['movieId'] == movid])
        movs.append((movie_names[movid], rat_count))

    for mov in sorted(movs, key=lambda tup: tup[1], reverse=True)[:10]:
        print("\t", mov[0])
# Out:
# Cluster #0
# 	 Independence Day (a.k.a. ID4) (1996)
# 	 Speed (1994)
# 	 Shrek (2001)
# 	 Dances with Wolves (1990)
# 	 Beauty and the Beast (1991)
# 	 Mrs. Doubtfire (1993)
# 	 Die Hard: With a Vengeance (1995)
# 	 Titanic (1997)
# 	 Monsters, Inc. (2001)
# 	 Beautiful Mind, A (2001)
# Cluster #1
# 	 Ace Ventura: Pet Detective (1994)
# 	 Mask, The (1994)
# 	 Stargate (1994)
# 	 Dumb & Dumber (Dumb and Dumber) (1994)
# 	 Austin Powers: The Spy Who Shagged Me (1999)
# 	 Home Alone (1990)
# 	 Star Trek: Generations (1994)
# 	 Clueless (1995)
# 	 Outbreak (1995)
# 	 Happy Gilmore (1996)
# Cluster #2
# 	 Police Academy: Mission to Moscow (1994)
# 	 But I'm a Cheerleader (1999)
# 	 Dark Days (2000)
# 	 Wackness, The (2008)
# 	 Curse of the Jade Scorpion, The (2001)
# 	 Blood and Wine (Blood & Wine) (1996)
# 	 Breakin' 2: Electric Boogaloo (1984)
# 	 Opera (1987)
# 	 Under the Sand (2000)
# 	 Carpool (1996)
# Cluster #3
# 	 Jurassic Park (1993)
# 	 True Lies (1994)
# 	 Men in Black (a.k.a. MIB) (1997)
# 	 Mission: Impossible (1996)
# 	 Pirates of the Caribbean: The Curse of the Black Pearl (2003)
# 	 Pretty Woman (1990)
# 	 X-Men (2000)
# 	 E.T. the Extra-Terrestrial (1982)
# 	 Spider-Man (2002)
# 	 Batman Begins (2005)
# Cluster #4
# 	 Anaconda (1997)
# 	 Problem Child (1990)
# 	 Flintstones in Viva Rock Vegas, The (2000)
# 	 Stop! Or My Mom Will Shoot (1992)
# 	 Spice World (1997)
# 	 Stuart Saves His Family (1995)
# 	 Catwoman (2004)
# 	 Jason X (2002)
# 	 Problem Child 2 (1991)
# 	 RocketMan (a.k.a. Rocket Man) (1997)
# Cluster #5
# 	 Shawshank Redemption, The (1994)
# 	 Rear Window (1954)
# 	 Lawrence of Arabia (1962)
# 	 Boondock Saints, The (2000)
# 	 Philadelphia Story, The (1940)
# 	 Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)
# 	 Streetcar Named Desire, A (1951)
# 	 Outlaw Josey Wales, The (1976)
# 	 Touch of Evil (1958)
# 	 Sweet Hereafter, The (1997)
# Cluster #6
# 	 Godzilla (1998)
# 	 I Know What You Did Last Summer (1997)
# 	 Richie Rich (1994)
# 	 Twilight (2008)
# 	 Superman III (1983)
# 	 The Scorpion King (2002)
# 	 Super Mario Bros. (1993)
# 	 Inspector Gadget (1999)
# 	 RoboCop 3 (1993)
# 	 Joe Dirt (2001)
# Cluster #7
# 	 Before Night Falls (2000)
# 	 Troll 2 (1990)
# 	 Submarine (2010)
# 	 Trust (1990)
# 	 3 Women (Three Women) (1977)
# 	 Game of Death (1978)
# 	 Clonus Horror, The (1979)
# 	 Midnight Clear, A (1992)
# 	 Holy Mountain, The (Montaña sagrada, La) (1973)
# 	 Eddie Izzard: Dress to Kill (1999)
# Cluster #8
# 	 Forrest Gump (1994)
# 	 Silence of the Lambs, The (1991)
# 	 Braveheart (1995)
# 	 Toy Story (1995)
# 	 American Beauty (1999)
# 	 Apollo 13 (1995)
# 	 Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)
# 	 Lord of the Rings: The Fellowship of the Ring, The (2001)
# 	 Fugitive, The (1993)
# 	 Saving Private Ryan (1998)
# Cluster #9
# 	 Star Wars: Episode I - The Phantom Menace (1999)
# 	 Matrix Reloaded, The (2003)
# 	 Matrix Revolutions, The (2003)
# 	 Mr. & Mrs. Smith (2005)
# 	 Scary Movie (2000)
# 	 Day After Tomorrow, The (2004)
# 	 Planet of the Apes (2001)
# 	 Da Vinci Code, The (2006)
# 	 Cell, The (2000)
# 	 Fast and the Furious, The (2001)
# Cluster #10
# 	 GoldenEye (1995)
# 	 Rock, The (1996)
# 	 Indiana Jones and the Temple of Doom (1984)
# 	 Sleepless in Seattle (1993)
# 	 Crimson Tide (1995)
# 	 While You Were Sleeping (1995)
# 	 Face/Off (1997)
# 	 Patriot, The (2000)
# 	 Abyss, The (1989)
# 	 Air Force One (1997)
# Cluster #11
# 	 Batman (1989)
# 	 Aladdin (1992)
# 	 Babe (1995)
# 	 Minority Report (2002)
# 	 Catch Me If You Can (2002)
# 	 Breakfast Club, The (1985)
# 	 Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000)
# 	 Donnie Darko (2001)
# 	 Ferris Bueller's Day Off (1986)
# 	 American Pie (1999)
# Cluster #12
# 	 Batman Forever (1995)
# 	 Twister (1996)
# 	 Waterworld (1995)
# 	 Net, The (1995)
# 	 Cliffhanger (1993)
# 	 Armageddon (1998)
# 	 Broken Arrow (1996)
# 	 Santa Clause, The (1994)
# 	 Demolition Man (1993)
# 	 Mission: Impossible II (2000)
# Cluster #13
# 	 Ace Ventura: When Nature Calls (1995)
# 	 Nutty Professor, The (1996)
# 	 Honey, I Shrunk the Kids (1989)
# 	 Blair Witch Project, The (1999)
# 	 Coneheads (1993)
# 	 Judge Dredd (1995)
# 	 Cable Guy, The (1996)
# 	 Johnny Mnemonic (1995)
# 	 Mortal Kombat (1995)
# 	 Species (1995)
# Cluster #14
# 	 Pulp Fiction (1994)
# 	 Matrix, The (1999)
# 	 Star Wars: Episode IV - A New Hope (1977)
# 	 Terminator 2: Judgment Day (1991)
# 	 Schindler's List (1993)
# 	 Fight Club (1999)
# 	 Star Wars: Episode V - The Empire Strikes Back (1980)
# 	 Usual Suspects, The (1995)
# 	 Seven (a.k.a. Se7en) (1995)
# 	 Star Wars: Episode VI - Return of the Jedi (1983)

# %%
#Changing the data into a format the our precision k algorithm would take 

user_ids = dfratings['userId'].values
movie_ids = dfratings['movieId'].values
true_ratings = dfratings['rating'].values

predicted_ratings2 = predicted_ratings 

data = []
for user_id, movie_id, true_rating, predicted_rating in zip(user_ids, movie_ids, true_ratings, predicted_ratings2):
    data.append((user_id, movie_id, true_rating, predicted_rating))

user_predictions = {}
for user_id, movie_id, true_rating, predicted_rating in data:
    if user_id not in user_predictions:
        user_predictions[user_id] = []
    user_predictions[user_id].append((movie_id, true_rating, predicted_rating))

# Sort each user's predictions by predicted rating in descending order
for user_id in user_predictions:
    user_predictions[user_id] = sorted(user_predictions[user_id], key=lambda x: x[2], reverse=True)

# %%
# usage
k = 15  # Top K recommendations
precision_k = precision_at_k(user_predictions, k)
print(f"Precision@{k}: {precision_k:.4f}")
# Out:
# Precision@15: 0.5534

# %%
del model 
del optimizer

# %%
# import torch
# import torch.nn as nn
# import torch.optim as optim
# import numpy as np

# # Precision@K Function
# def precision_at_k(recommended_movies, relevant_movies, k):
#     """
#     Compute Precision@K.
    
#     Parameters:
#     - recommended_movies: List of top K recommended movie IDs.
#     - relevant_movies: Set of relevant movie IDs for the user.
#     - k: Number of top recommendations to consider.

#     Returns:
#     - Precision@K score
#     """
#     if len(recommended_movies) == 0:
#         return 0  # Avoid division by zero

#     # Take only the top K recommendations
#     recommended_top_k = recommended_movies[:k]
#     relevant_count = sum(1 for movie in recommended_top_k if movie in relevant_movies)

#     return relevant_count / k  # Precision = relevant recommendations / total recommendations


# # Define the NCF Model
# class NCF(nn.Module):
#     def __init__(self, num_users, num_items, embedding_dim=32):
#         super(NCF, self).__init__()
#         self.user_embedding = nn.Embedding(num_users, embedding_dim)
#         self.item_embedding = nn.Embedding(num_items, embedding_dim)
#         self.fc = nn.Sequential(
#             nn.Linear(embedding_dim * 2, 64),
#             nn.ReLU(),
#             nn.Linear(64, 32),
#             nn.ReLU(),
#             nn.Linear(32, 1),
#             nn.Sigmoid()  # Output between 0 and 1
#         )

#     def forward(self, user_ids, movie_ids):
#         user_embeds = self.user_embedding(user_ids)
#         item_embeds = self.item_embedding(movie_ids)
#         concat = torch.cat([user_embeds, item_embeds], dim=-1)
#         return self.fc(concat).squeeze()

    
# # Function to Train the Model
# def train_ncf(model, train_loader, num_epochs=10, lr=0.001):
#     criterion = nn.BCELoss()
#     optimizer = optim.Adam(model.parameters(), lr=lr)

#     for epoch in range(num_epochs):
#         for user_ids, movie_ids, ratings in train_loader:
#             optimizer.zero_grad()
#             predictions = model(user_ids, movie_ids)
#             loss = criterion(predictions, ratings)
#             loss.backward()
#             optimizer.step()

#         print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}")


# # Function to Get Top-K Recommendations
# def get_top_k_recommendations(model, user_id, movie_ids, k=10):
#     user_tensor = torch.tensor([user_id] * len(movie_ids), dtype=torch.long)
#     movie_tensor = torch.tensor(movie_ids, dtype=torch.long)

#     with torch.no_grad():
#         scores = model(user_tensor, movie_tensor)

#     # Sort movies by predicted rating (descending order) and take top-K
#     top_k_movies = [movie_ids[i] for i in torch.argsort(scores, descending=True)[:k]]
#     return top_k_movies

# %%
# # Load Data & Train the Model
# num_users = dfratings['userId'].max() + 1
# num_items = dfratings['movieId'].max() + 1

# %%
# import pandas as pd

# # Create mappings from original IDs to zero-based IDs
# user_id_map = {id_: idx for idx, id_ in enumerate(dfratings['userId'].unique())}
# movie_id_map = {id_: idx for idx, id_ in enumerate(dfratings['movieId'].unique())}

# # Apply mapping
# dfratings['userId'] = dfratings['userId'].map(user_id_map)
# dfratings['movieId'] = dfratings['movieId'].map(movie_id_map)

# user_ids = torch.tensor(dfratings['userId'].values, dtype=torch.long)
# movie_ids = torch.tensor(dfratings['movieId'].values, dtype=torch.long)
# ratings = torch.tensor((dfratings['rating'].values >= 3.5).astype(float), dtype=torch.float32)

# %%
# # Initialize and Train Model
# num_users = dfratings['userId'].max() + 1  # Add 1 to include last index
# # num_items = dfratings['movieId'].max() + 1


# ncf_model = NCF(num_users, num_items)
# train_ncf(ncf_model, train_loader, num_epochs=10, lr=0.001)

# %%
# # Get Predictions for Recommendations
# def get_top_k_recommendations(model, user_id, movie_ids, k=10):
#     user_tensor = torch.tensor([user_id] * len(movie_ids), dtype=torch.long)
#     movie_tensor = torch.tensor(movie_ids, dtype=torch.long)
    
#     with torch.no_grad():
#         scores = model(user_tensor, movie_tensor)
    
#     top_k_indices = scores.argsort(descending=True)[:k]
#     return movie_ids[top_k_indices]

# %%
# ncf_model = NCF(num_users, num_items)
# train_ncf(ncf_model, train_loader, num_epochs=10, lr=0.001)

# # Validate using Precision@K
# k = 10  # Top-K recommendations
# all_precisions = []

# for user_id in dfratings['userId'].unique():
#     relevant_movies = set(dfratings[(dfratings['userId'] == user_id) & (dfratings['rating'] >= 3.5)]['movieId'])

#     if len(relevant_movies) == 0:
#         continue  # Skip users without relevant movies

#     recommended_movies = get_top_k_recommendations(ncf_model, user_id, dfratings['movieId'].unique(), k)
#     precision = precision_at_k(recommended_movies, relevant_movies, k)
#     all_precisions.append(precision)

# # Compute Final Validation Score
# final_precision_k = np.mean(all_precisions)
# print(f"Final Precision@{k}: {final_precision_k:.4f}")

# %%
# # Example Usage
# user_to_recommend = 1  # Change this to a valid user ID
# all_movie_ids = dfratings['movieId'].unique()
# top_k_movies = get_top_k_recommendations(ncf_model, user_to_recommend, all_movie_ids, k=10)
# print("Recommended Movies:", top_k_movies)
